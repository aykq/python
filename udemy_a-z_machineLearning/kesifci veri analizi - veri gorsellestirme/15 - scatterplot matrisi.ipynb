# %% [markdown]
# ## scatterplot matrisi

# %%
import seaborn as sns

iris = sns.load_dataset("iris")
df = iris.copy()
df.head()

# iris veri seti = cicek turleri ve ozellikleri
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.dtypes

# 4 sayisal degisken
# 1 tane kategorik degisken
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.shape

# 150 gozlem (satır), 5 degisken (sutun)
# Out:
# (150, 5)

# %%
sns.pairplot(df)

# satir ve sutun baz alinarak olusturulmus olan grafigin yapisal bir formu yoksa,
# o iki degisken arasinda bir iliski olmadigi anlamina gelir

# noktalar birbirinden farkli yerlerde kumeleniyorsa, caprazlama ile gozlemleyebilecek oldugumuz alt gruplar vardır

# %%
sns.pairplot(df, hue='species')

# bir ustte yazilan farkli farkli gruplanmalarin ture gore renklendirildigi grafikler asagidaki gibidir

# %%
sns.pairplot(df, hue='species', markers=['o', 's', 'D'])

# %%
sns.pairplot(df, kind='reg')

# %%
sns.pairplot(df, kind='reg', hue='species')
